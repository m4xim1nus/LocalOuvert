# %%
import pandas as pd

# %%
regions = pd.read_csv("../../data/communities/processed_data/identifiants_regions_2023.csv")
departements = pd.read_csv("../../data/communities/processed_data/identifiants_departements_2023.csv")
communes = pd.read_csv("../../data/communities/processed_data/identifiants_communes_2023.csv")
interco = pd.read_csv("../../data/communities/processed_data/identifiants_epci_2023.csv")
infos_collectivites = pd.read_csv("../../data/communities/processed_data/infos_collectivites.csv")

# %%
print("Taille des DataFrames:")
print(f"Regions: {regions.shape}")
print(f"Departements: {departements.shape}")
print(f"Communes: {communes.shape}")
print(f"Interco: {interco.shape}")
print(f"Infos Collectivites: {infos_collectivites.shape}")
# Out:
# Taille des DataFrames:
# Regions: (17, 5)
# Departements: (98, 7)
# Communes: (34968, 9)
# Interco: (1267, 7)
# Infos Collectivites: (36352, 15)

# %%
print(communes.head)
# Out:
# <bound method NDFrame.head of                            nom      SIREN    COG type code_departement
# 0      L'Abergement-Clémenciat  210100012  01001  COM               01  \
# 1        L'Abergement-de-Varey  210100020  01002  COM               01
# 2            Ambérieu-en-Bugey  210100046  01004  COM               01
# 3          Ambérieux-en-Dombes  210100053  01005  COM               01
# 4                      Ambléon  210100061  01006  COM               01
# ...                        ...        ...    ...  ...              ...
# 34963            M'Tsangamouji  200008829  97613  COM              976
# 34964                 Ouangani  200008852  97614  COM              976
# 34965                 Pamandzi  200008860  97615  COM              976
# 34966                     Sada  200008878  97616  COM              976
# 34967                 Tsingoni  200008886  97617  COM              976
#
#       code_departement_3digits  code_region  population         EPCI
# 0                          001           84         794  200069193.0
# 1                          001           84         249  240100883.0
# 2                          001           84       14428  240100883.0
# 3                          001           84        1723  200042497.0
# 4                          001           84         117  200040350.0
# ...                        ...          ...         ...          ...
# 34963                      976            6        6586  200059871.0
# 34964                      976            6       10393  200059871.0
# 34965                      976            6       11802  200050532.0
# 34966                      976            6       11619  200059871.0
# 34967                      976            6       14235  200059871.0
#
# [34968 rows x 9 columns]>

# %%
print("Infos Collectivites:")
print(infos_collectivites.describe(include='all'))

print("Nombre de valeurs manquantes par colonne :")
print(infos_collectivites.isnull().sum())

print("Nombre de lignes dupliquées :")
print(infos_collectivites.duplicated().sum())

print("Types uniques de collectivités :")
print(infos_collectivites['type'].unique())
# Out:
# Infos Collectivites:
#                    nom         SIREN   type    COG COG_3digits
# count            36352  3.635200e+04  36352  35084          98  \
# unique           34058           NaN      9  35052          97
# top     Sainte-Colombe           NaN    COM  53249         67A
# freq                12           NaN  34969      3           2
# mean               NaN  2.144622e+08    NaN    NaN         NaN
# std                NaN  5.388390e+06    NaN    NaN         NaN
# min                NaN  2.000002e+08    NaN    NaN         NaN
# 25%                NaN  2.122005e+08    NaN    NaN         NaN
# 50%                NaN  2.146029e+08    NaN    NaN         NaN
# 75%                NaN  2.167023e+08    NaN    NaN         NaN
# max                NaN  2.497401e+08    NaN    NaN         NaN
#
#        code_departement code_departement_3digits code_region    population
# count             36237                    36237       36335  3.635200e+04  \
# unique              172                      172          33           NaN
# top                  62                      062          44           NaN
# freq                908                      908        5279           NaN
# mean                NaN                      NaN         NaN  7.619098e+03
# std                 NaN                      NaN         NaN  1.269825e+05
# min                 NaN                      NaN         NaN  0.000000e+00
# 25%                 NaN                      NaN         NaN  2.110000e+02
# 50%                 NaN                      NaN         NaN  5.000000e+02
# 75%                 NaN                      NaN         NaN  1.366000e+03
# max                 NaN                      NaN         NaN  1.229128e+07
#
#                 EPCI                                           url-ptf
# count   3.492300e+04                                               396  \
# unique           NaN                                               372
# top              NaN  http://datarmor.cotesdarmor.fr/web/guest/donnees
# freq             NaN                                                17
# mean    2.125833e+08                                               NaN
# std     2.006724e+07                                               NaN
# min     2.000002e+08                                               NaN
# 25%     2.000660e+08                                               NaN
# 50%     2.000697e+08                                               NaN
# 75%     2.410005e+08                                               NaN
# max     2.497401e+08                                               NaN
#
#                                              url-datagouv
# count                                                 608  \
# unique                                                602
# top     https://www.data.gouv.fr/fr/organizations/5aec...
# freq                                                    2
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                      id-datagouv     merge       ptf
# count                        578       844       815
# unique                       573         3       169
# top     534fff89a3a7292c64a77eb7  datagouv  DataGouv
# freq                           2       450       451
# mean                         NaN       NaN       NaN
# std                          NaN       NaN       NaN
# min                          NaN       NaN       NaN
# 25%                          NaN       NaN       NaN
# 50%                          NaN       NaN       NaN
# 75%                          NaN       NaN       NaN
# max                          NaN       NaN       NaN
# Nombre de valeurs manquantes par colonne :
# nom                             0
# SIREN                           0
# type                            0
# COG                          1268
# COG_3digits                 36254
# code_departement              115
# code_departement_3digits      115
# code_region                    17
# population                      0
# EPCI                         1429
# url-ptf                     35956
# url-datagouv                35744
# id-datagouv                 35774
# merge                       35508
# ptf                         35537
# dtype: int64
# Nombre de lignes dupliquées :
# 1
# Types uniques de collectivités :
# ['REG' 'CTU' 'DEP' 'COM' 'CC' 'MET' 'CA' 'CU' 'EPT']

# %%
print("Exemple de lignes pour chaque type de collectivité :")
for t in infos_collectivites['type'].unique():
    print(f"\nType : {t}")
    print(infos_collectivites[infos_collectivites['type'] == t].head())
# Out:
# Exemple de lignes pour chaque type de collectivité :
#
# Type : REG
#   COG                      nom type      SIREN  population COG_3digits
# 0  01               Guadeloupe  REG  239710015      396153         NaN  \
# 3  04               La Réunion  REG  239740012      863063         NaN
# 4  11            Île-de-France  REG  237500079    12291279         NaN
# 5  24      Centre-Val de Loire  REG  234500023     2634852         NaN
# 6  27  Bourgogne-Franche-Comté  REG  200053726     2885864         NaN
#
#   code_region code_departement code_departement_3digits  EPCI
# 0         NaN              NaN                      NaN   NaN
# 3         NaN              NaN                      NaN   NaN
# 4         NaN              NaN                      NaN   NaN
# 5         NaN              NaN                      NaN   NaN
# 6         NaN              NaN                      NaN   NaN
#
# Type : CTU
#    COG         nom type      SIREN  population COG_3digits code_region
# 1   02  Martinique  CTU  200055507      377711         NaN         NaN  \
# 2   03      Guyane  CTU  200052678      271124         NaN         NaN
# 16  94       Corse  CTU  200076958      340233         NaN         NaN
#
#    code_departement code_departement_3digits  EPCI
# 1               NaN                      NaN   NaN
# 2               NaN                      NaN   NaN
# 16              NaN                      NaN   NaN
#
# Type : DEP
#    COG                      nom type      SIREN  population COG_3digits
# 17  01                      Ain  DEP  220100010      659180         001  \
# 18  02                    Aisne  DEP  220200026      546527         002
# 19  03                   Allier  DEP  220300016      347035         003
# 20  04  Alpes-de-Haute-Provence  DEP  220400014      168381         004
# 21  05             Hautes-Alpes  DEP  220500011      145883         005
#
#    code_region code_departement code_departement_3digits  EPCI
# 17          84              NaN                      NaN   NaN
# 18          32              NaN                      NaN   NaN
# 19          84              NaN                      NaN   NaN
# 20          93              NaN                      NaN   NaN
# 21          93              NaN                      NaN   NaN
#
# Type : COM
#        COG                      nom type      SIREN  population COG_3digits
# 115  01001  L'Abergement-Clémenciat  COM  210100012         794         NaN  \
# 116  01002    L'Abergement-de-Varey  COM  210100020         249         NaN
# 117  01004        Ambérieu-en-Bugey  COM  210100046       14428         NaN
# 118  01005      Ambérieux-en-Dombes  COM  210100053        1723         NaN
# 119  01006                  Ambléon  COM  210100061         117         NaN
#
#     code_region code_departement code_departement_3digits         EPCI
# 115          84               01                      001  200069193.0
# 116          84               01                      001  240100883.0
# 117          84               01                      001  240100883.0
# 118          84               01                      001  200042497.0
# 119          84               01                      001  200040350.0
#
# Type : CC
#        COG                                    nom type      SIREN  population
# 35083  NaN        CC du Causse de Labastide-Murat   CC  244600573        3979  \
# 35084  NaN       CC du Cordais et du Causse (4 C)   CC  200034064        4675
# 35085  NaN                      CC Cœur de Brenne   CC  243600343        4848
# 35086  NaN  CC du Territoire de Fresnes-en-Woëvre   CC  245501176        4930
# 35087  NaN            CC de la Montagne d'Ardèche   CC  200072007        5013
#
#       COG_3digits code_region code_departement code_departement_3digits  EPCI
# 35083         NaN          76               46                      046   NaN
# 35084         NaN          76               81                      081   NaN
# 35085         NaN          24               36                      036   NaN
# 35086         NaN          44               55                      055   NaN
# 35087         NaN          84               07                      007   NaN
#
# Type : MET
#        COG                            nom type      SIREN  population
# 35727  NaN  Métropole Européenne de Lille  MET  200093201       24566  \
# 36295  NaN                Brest Métropole  MET  242900314      214022
# 36297  NaN                 Metz Métropole  MET  200039865      225082
# 36302  NaN                Dijon Métropole  MET  242100410      258782
# 36303  NaN       Métropole du Grand Nancy  MET  245400676      261055
#
#       COG_3digits code_region code_departement code_departement_3digits  EPCI
# 35727         NaN          32               59                      059   NaN
# 36295         NaN          53               29                      029   NaN
# 36297         NaN          44               57                      057   NaN
# 36302         NaN          27               21                      021   NaN
# 36303         NaN          44               54                      054   NaN
#
# Type : CA
#        COG                                                nom type      SIREN
# 35848  NaN                                 CA du Grand Verdun   CA  200049187  \
# 35860  NaN                                 CA du Grand Guéret   CA  200034825
# 35907  NaN                              CA Pays Foix-Varilhes   CA  200067791
# 35910  NaN                                       CA de Vesoul   CA  247000011
# 35939  NaN  CA ECLA  (Espace Communautaire Lons Agglomérat...   CA  200071116
#
#        population COG_3digits code_region code_departement
# 35848       29289         NaN          44               55  \
# 35860       30093         NaN          75               23
# 35907       32725         NaN          76               09
# 35910       33484         NaN          27               70
# 35939       35945         NaN          27               39
#
#       code_departement_3digits  EPCI
# 35848                      055   NaN
# 35860                      023   NaN
# 35907                      009   NaN
# 35910                      070   NaN
# 35939                      039   NaN
#
# Type : CU
#        COG                               nom type      SIREN  population
# 36103  NaN                      CU d'Alençon   CU  246100663       57975  \
# 36204  NaN  CU Le Creusot Montceau-les-Mines   CU  247100290       95944
# 36234  NaN                        CU d'Arras   CU  200033579      109759
# 36285  NaN              CU du Grand Poitiers   CU  200069854      197627
# 36286  NaN       CU Grand Besançon Métropole   CU  242500361      198250
#
#       COG_3digits code_region code_departement code_departement_3digits  EPCI
# 36103         NaN       28,52            61,72                    61,72   NaN
# 36204         NaN          27               71                      071   NaN
# 36234         NaN          32               62                      062   NaN
# 36285         NaN          75               86                      086   NaN
# 36286         NaN          27               25                      025   NaN
#
# Type : EPT
#        COG                         nom type      SIREN  population
# 36317  NaN  Grand Paris Sud Est Avenir  EPT  200058006      316295  \
# 36320  NaN     Grand Paris Seine Ouest  EPT  200057974      322928
# 36324  NaN        Paris Terres d'Envol  EPT  200058097      366709
# 36325  NaN     Grand Paris - Grand Est  EPT  200058790      399809
# 36326  NaN      Vallée Sud Grand Paris  EPT  200057966      405491
#
#       COG_3digits code_region code_departement code_departement_3digits  EPCI
# 36317         NaN          11               94                      094   NaN
# 36320         NaN          11               92                      092   NaN
# 36324         NaN          11               93                      093   NaN
# 36325         NaN          11               93                      093   NaN
# 36326         NaN          11               92                      092   NaN

# %%
unique_types = infos_collectivites["type"].unique()

for collectivity_type in unique_types:
    print(f"Type: {collectivity_type}")
    display(infos_collectivites[infos_collectivites["type"] == collectivity_type].head(3))
    print("\n")
# Out:
# Type: REG
#              nom      SIREN type COG COG_3digits code_departement
# 0     Guadeloupe  239710015  REG  01         NaN              NaN  \
# 3     La Réunion  239740012  REG  04         NaN              NaN
# 4  Île-de-France  237500079  REG  11         NaN              NaN
#
#   code_departement_3digits code_region  population  EPCI
# 0                      NaN         NaN      396153   NaN  \
# 3                      NaN         NaN      863063   NaN
# 4                      NaN         NaN    12291279   NaN
#
#                                              url-ptf
# 0  https://regionguadeloupe.opendatasoft.com/expl...  \
# 3  https://data.regionreunion.com/explore/?disjun...
# 4  https://data.iledefrance.fr/explore/?refine.pu...
#
#                                         url-datagouv
# 0                                                NaN  \
# 3                                                NaN
# 4  https://www.data.gouv.fr/fr/organizations/534f...
#
#                 id-datagouv         merge                      ptf
# 0                       NaN           ptf                 KaruData
# 3                       NaN           ptf               La Réunion
# 4  534fffa8a3a7292c64a780c8  ptf+datagouv  Ile-de-France, DataGouv
# Type: CTU
#            nom      SIREN type COG COG_3digits code_departement
# 1   Martinique  200055507  CTU  02         NaN              NaN  \
# 2       Guyane  200052678  CTU  03         NaN              NaN
# 16       Corse  200076958  CTU  94         NaN              NaN
#
#    code_departement_3digits code_region  population  EPCI url-ptf
# 1                       NaN         NaN      377711   NaN     NaN  \
# 2                       NaN         NaN      271124   NaN     NaN
# 16                      NaN         NaN      340233   NaN     NaN
#
#    url-datagouv id-datagouv merge  ptf
# 1           NaN         NaN   NaN  NaN
# 2           NaN         NaN   NaN  NaN
# 16          NaN         NaN   NaN  NaN
# Type: DEP
#        nom      SIREN type COG COG_3digits code_departement
# 17     Ain  220100010  DEP  01         001              NaN  \
# 18   Aisne  220200026  DEP  02         002              NaN
# 19  Allier  220300016  DEP  03         003              NaN
#
#    code_departement_3digits code_region  population  EPCI
# 17                      NaN          84      659180   NaN  \
# 18                      NaN          32      546527   NaN
# 19                      NaN          84      347035   NaN
#
#                                               url-ptf
# 17  http://departement-ain.opendata.arcgis.com/dat...  \
# 18                                                NaN
# 19                                                NaN
#
#                                          url-datagouv
# 17  https://www.data.gouv.fr/fr/organizations/5851...  \
# 18                                                NaN
# 19                                                NaN
#
#                  id-datagouv         merge            ptf
# 17  5851009688ee3870fbc65bb3  ptf+datagouv  Ain, DataGouv
# 18                       NaN           NaN            NaN
# 19                       NaN           NaN            NaN
# Type: COM
#                          nom      SIREN type    COG COG_3digits
# 115  L'Abergement-Clémenciat  210100012  COM  01001         NaN  \
# 116    L'Abergement-de-Varey  210100020  COM  01002         NaN
# 117        Ambérieu-en-Bugey  210100046  COM  01004         NaN
#
#     code_departement code_departement_3digits code_region  population
# 115               01                      001          84         794  \
# 116               01                      001          84         249
# 117               01                      001          84       14428
#
#             EPCI url-ptf url-datagouv id-datagouv merge  ptf
# 115  200069193.0     NaN          NaN         NaN   NaN  NaN
# 116  240100883.0     NaN          NaN         NaN   NaN  NaN
# 117  240100883.0     NaN          NaN         NaN   NaN  NaN
# Type: CC
#                                     nom      SIREN type  COG COG_3digits
# 35084   CC du Causse de Labastide-Murat  244600573   CC  NaN         NaN  \
# 35085  CC du Cordais et du Causse (4 C)  200034064   CC  NaN         NaN
# 35086                 CC Cœur de Brenne  243600343   CC  NaN         NaN
#
#       code_departement code_departement_3digits code_region  population  EPCI
# 35084               46                      046          76        3979   NaN  \
# 35085               81                      081          76        4675   NaN
# 35086               36                      036          24        4848   NaN
#
#       url-ptf url-datagouv id-datagouv merge  ptf
# 35084     NaN          NaN         NaN   NaN  NaN
# 35085     NaN          NaN         NaN   NaN  NaN
# 35086     NaN          NaN         NaN   NaN  NaN
# Type: MET
#                                  nom      SIREN type  COG COG_3digits
# 35728  Métropole Européenne de Lille  200093201  MET  NaN         NaN  \
# 36297                Brest Métropole  242900314  MET  NaN         NaN
# 36299                 Metz Métropole  200039865  MET  NaN         NaN
#
#       code_departement code_departement_3digits code_region  population  EPCI
# 35728               59                      059          32       24566   NaN  \
# 36297               29                      029          53      214022   NaN
# 36299               57                      057          44      225082   NaN
#
#                                                  url-ptf
# 35728                                                NaN  \
# 36297  https://opendata.brest-metropole.fr/explore/?s...
# 36299                                                NaN
#
#                                             url-datagouv
# 35728                                                NaN  \
# 36297  https://www.data.gouv.fr/fr/organizations/534f...
# 36299  https://www.data.gouv.fr/fr/organizations/53fd...
#
#                     id-datagouv         merge                        ptf
# 35728                       NaN           NaN                        NaN
# 36297  534fff5ba3a7292c64a77d19  ptf+datagouv  Brest Métropole, DataGouv
# 36299  53fd1263a3a729390ba568a4      datagouv                   DataGouv
# Type: CA
#                          nom      SIREN type  COG COG_3digits
# 35849     CA du Grand Verdun  200049187   CA  NaN         NaN  \
# 35861     CA du Grand Guéret  200034825   CA  NaN         NaN
# 35908  CA Pays Foix-Varilhes  200067791   CA  NaN         NaN
#
#       code_departement code_departement_3digits code_region  population  EPCI
# 35849               55                      055          44       29289   NaN  \
# 35861               23                      023          75       30093   NaN
# 35908               09                      009          76       32725   NaN
#
#       url-ptf                                       url-datagouv
# 35849     NaN                                                NaN  \
# 35861     NaN  https://www.data.gouv.fr/fr/organizations/5cc0...
# 35908     NaN  https://www.data.gouv.fr/fr/organizations/5bd9...
#
#                     id-datagouv     merge       ptf
# 35849                       NaN       NaN       NaN
# 35861  5cc0c79b8b4c414c13d12d0a  datagouv  DataGouv
# 35908  5bd9cd77634f413406c077fd  datagouv  DataGouv
# Type: CU
#                                     nom      SIREN type  COG COG_3digits
# 36105                      CU d'Alençon  246100663   CU  NaN         NaN  \
# 36206  CU Le Creusot Montceau-les-Mines  247100290   CU  NaN         NaN
# 36236                        CU d'Arras  200033579   CU  NaN         NaN
#
#       code_departement code_departement_3digits code_region  population  EPCI
# 36105            61,72                    61,72       28,52       57975   NaN  \
# 36206               71                      071          27       95944   NaN
# 36236               62                      062          32      109759   NaN
#
#       url-ptf url-datagouv id-datagouv merge  ptf
# 36105     NaN          NaN         NaN   NaN  NaN
# 36206     NaN          NaN         NaN   NaN  NaN
# 36236     NaN          NaN         NaN   NaN  NaN
# Type: EPT
#                               nom      SIREN type  COG COG_3digits
# 36319  Grand Paris Sud Est Avenir  200058006  EPT  NaN         NaN  \
# 36322     Grand Paris Seine Ouest  200057974  EPT  NaN         NaN
# 36326        Paris Terres d'Envol  200058097  EPT  NaN         NaN
#
#       code_departement code_departement_3digits code_region  population  EPCI
# 36319               94                      094          11      316295   NaN  \
# 36322               92                      092          11      322928   NaN
# 36326               93                      093          11      366709   NaN
#
#                                                  url-ptf
# 36319                      https://data.sudestavenir.fr/  \
# 36322  https://data.seineouest.fr/explore/?sort=recor...
# 36326                                                NaN
#
#                                             url-datagouv
# 36319                                                NaN  \
# 36322  https://www.data.gouv.fr/fr/organizations/543e...
# 36326                                                NaN
#
#                     id-datagouv         merge
# 36319                       NaN           ptf  \
# 36322  543e77eb88ee380c0d999949  ptf+datagouv
# 36326                       NaN           NaN
#
#                                      ptf
# 36319                                NaN
# 36322  Grand Paris Seine Ouest, DataGouv
# 36326                                NaN

# %%
epci_communes = pd.read_excel("../../data/communities/scrapped_data/gouv_colloc/epcicom2023.xlsx", dtype={"siren": str, "siren_membre": str})

# %%
epci_communes_grouped = epci_communes.groupby('siren_membre')['siren'].count().reset_index()
epci_communes_grouped.columns = ['siren_membre', 'epci_count']

# %%
multiple_epci = epci_communes_grouped[epci_communes_grouped['epci_count'] > 1]
print("Nombre de communes avec plusieurs EPCI :", len(multiple_epci))
# Out:
# Nombre de communes avec plusieurs EPCI : 0
