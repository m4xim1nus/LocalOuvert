# %% [markdown]
# # Datasets Explorer

# %% [markdown]
# ## Importation des bibliothèques

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Chargement des fichiers CSV

# %%
datasets_file_folder = Path("../../data/datasets/")

filtered_datasets_filename = 'filtered_datasets.csv'
filtered_datafiles_filename = 'filtered_datafiles.csv'
filtered_detailed_data_filename = 'filtered_detailed_data.csv'

filtered_datasets_df = pd.read_csv(datasets_file_folder / filtered_datasets_filename)
filtered_datafiles_df = pd.read_csv(datasets_file_folder / filtered_datafiles_filename)
filtered_detailed_data_df = pd.read_csv(datasets_file_folder / filtered_detailed_data_filename)
# Out:
# C:\Users\Max\AppData\Local\Temp\ipykernel_9656\127449740.py:9: DtypeWarning: Columns (2,3,4,7,9,10,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   filtered_detailed_data_df = pd.read_csv(datasets_file_folder / filtered_detailed_data_filename)

# %% [markdown]
# ## Exploration des données

# %%
# Affichage des 5 premières lignes de chaque dataframe
print("Filtered Datasets:")
display(filtered_datasets_df.head())

print("\nFiltered Datafiles:")
display(filtered_datafiles_df.head())

print("\nFiltered Detailed Data:")
display(filtered_detailed_data_df.head())
# Out:
# Filtered Datasets:
#                          id
# 0  6430af207f3e31d2c253867d  \
# 1  642cbb15b047f22ca7538678
# 2  63d85a7f4c2526cadb40440d
# 3  63d071ccf66c897ec1404414
# 4  63a24f0c207bdb78a99dde9e
#
#                                                title
# 0  Données essentielles des conventions de subven...  \
# 1  Données essentielles des conventions de subven...
# 2    Interventions de la Région des Pays de la Loire
# 3  Données essentielles des conventions de subven...
# 4  Données essentielles des conventions de subven...
#
#                                                  url
# 0  http://www.data.gouv.fr/fr/datasets/1646230541...  \
# 1  http://www.data.gouv.fr/fr/datasets/1646230541...
# 2  http://www.data.gouv.fr/fr/datasets/interventi...
# 3  http://www.data.gouv.fr/fr/datasets/1646230541...
# 4  http://www.data.gouv.fr/fr/datasets/1646230541...
#
#                                          description
# 0  Données essentielles des conventions de subven...  \
# 1  Données essentielles des conventions de subven...
# 2  Liste des interventions (Aides, Appels à proje...
# 3  Données essentielles des conventions de subven...
# 4  Données essentielles des conventions de subven...
#
#                   organization           organization_id frequency
# 0             Région GRAND EST  55df259f88ee386e57a46ec2       NaN
# 1             Région GRAND EST  55df259f88ee386e57a46ec2       NaN
# 2  Région des Pays de la Loire  534fffa7a3a7292c64a780c5   unknown
# 3             Région GRAND EST  55df259f88ee386e57a46ec2       NaN
# 4             Région GRAND EST  55df259f88ee386e57a46ec2       NaN
# Filtered Datafiles:
#                        id_x
# 0  6430af207f3e31d2c253867d  \
# 1  642cbb15b047f22ca7538678
# 2  63d85a7f4c2526cadb40440d
# 3  63d071ccf66c897ec1404414
# 4  63a24f0c207bdb78a99dde9e
#
#                                              title_x
# 0  Données essentielles des conventions de subven...  \
# 1  Données essentielles des conventions de subven...
# 2    Interventions de la Région des Pays de la Loire
# 3  Données essentielles des conventions de subven...
# 4  Données essentielles des conventions de subven...
#
#                                                url_x
# 0  http://www.data.gouv.fr/fr/datasets/1646230541...  \
# 1  http://www.data.gouv.fr/fr/datasets/1646230541...
# 2  http://www.data.gouv.fr/fr/datasets/interventi...
# 3  http://www.data.gouv.fr/fr/datasets/1646230541...
# 4  http://www.data.gouv.fr/fr/datasets/1646230541...
#
#                                        description_x
# 0  Données essentielles des conventions de subven...  \
# 1  Données essentielles des conventions de subven...
# 2  Liste des interventions (Aides, Appels à proje...
# 3  Données essentielles des conventions de subven...
# 4  Données essentielles des conventions de subven...
#
#                   organization           organization_id frequency
# 0             Région GRAND EST  55df259f88ee386e57a46ec2       NaN  \
# 1             Région GRAND EST  55df259f88ee386e57a46ec2       NaN
# 2  Région des Pays de la Loire  534fffa7a3a7292c64a780c5   unknown
# 3             Région GRAND EST  55df259f88ee386e57a46ec2       NaN
# 4             Région GRAND EST  55df259f88ee386e57a46ec2       NaN
#
#                  dataset.id
# 0  6430af207f3e31d2c253867d  \
# 1  642cbb15b047f22ca7538678
# 2  63d85a7f4c2526cadb40440d
# 3  63d071ccf66c897ec1404414
# 4  63a24f0c207bdb78a99dde9e
#
#                                        dataset.title
# 0  Données essentielles des conventions de subven...  \
# 1  Données essentielles des conventions de subven...
# 2    Interventions de la Région des Pays de la Loire
# 3  Données essentielles des conventions de subven...
# 4  Données essentielles des conventions de subven...
#
#                                       dataset.slug  ... format      mime
# 0                                1646230541247-1-7  ...    csv       NaN  \
# 1                                1646230541247-1-6  ...    csv       NaN
# 2  interventions-de-la-region-des-pays-de-la-loire  ...    csv  text/csv
# 3                                1646230541247-1-5  ...    csv       NaN
# 4                                1646230541247-1-4  ...    csv       NaN
#
#   filesize checksum.type  checksum.value                  created_at
# 0      NaN           NaN             NaN         2023-04-07T00:00:00  \
# 1      NaN           NaN             NaN         2023-04-04T00:00:00
# 2      NaN           NaN             NaN  2023-01-31T01:02:07.319000
# 3      NaN           NaN             NaN         2023-01-24T00:00:00
# 4      NaN           NaN             NaN         2022-12-20T00:00:00
#
#                      modified downloads   harvest.created_at
# 0  2023-04-08T02:02:40.284000         0  2023-04-07T00:00:00  \
# 1  2023-04-05T02:04:37.379000         0  2023-04-04T00:00:00
# 2  2023-04-27T21:11:05.847000         0                  NaN
# 3  2023-01-25T01:03:24.644000         3  2023-01-24T00:00:00
# 4  2022-12-21T01:10:52.399000         2  2022-12-20T00:00:00
#
#           harvest.modified_at
# 0                         NaN
# 1                         NaN
# 2  2023-04-27T21:11:05.847000
# 3                         NaN
# 4                         NaN
#
# [5 rows x 31 columns]
# Filtered Detailed Data:
#       nomattribuant  idattribuant       dateconvention referencedecision
# 0  Région Grand Est  2.000523e+13  2019-01-21 00:00:00     SP 21/01/2019  \
# 1  Région Grand Est  2.000523e+13  2019-11-22 00:00:00     CP 22/11/2019
# 2  Région Grand Est  2.000523e+13  2019-11-22 00:00:00     CP 22/11/2019
# 3  Région Grand Est  2.000523e+13  2019-11-22 00:00:00     CP 22/11/2019
# 4  Région Grand Est  2.000523e+13  2019-11-22 00:00:00     CP 22/11/2019
#
#                                nombeneficiaire    idbeneficiaire
# 0              INSTITUT DE SOUDURE INDUSTRIE    41472896400019.0  \
# 1  ASS REGD'EDUCATION PERMANENTE DE LORRAINE    50253877000020.0
# 2             LYCEE DES METIERS FD ROOSEVELT    19680039500010.0
# 3                          BTP CFA GRAND EST    78334702400102.0
# 4  ASS OUVRIERE COMPAGNON DEVOIR TOUR FRANCE    77566202600050.0
#
#    rnabeneficiaire                                              objet
# 0              NaN    2019-15081 - FIFE INSTITUT DE SOUDURE INDUSTRIE  \
# 1              NaN           Appel à projets équip véhicules hybrides
# 2              NaN                             Appel à projet CFA 4.0
# 3              NaN  BTPCFA AUBE - Investissement 2019 - Appel à pr...
# 4              NaN  CFA COMPAGNONS - Investissement 2019 - Appel à...
#
#     montant             nature conditionsversement datesperiodeversement
# 0  60854.00  aide en numéraire              unique   2019-01-21 00:00:00  \
# 1  30000.00  aide en numéraire              unique   2019-11-22 00:00:00
# 2  32152.00  aide en numéraire              unique   2019-11-22 00:00:00
# 3  24201.96  aide en numéraire              unique   2019-11-22 00:00:00
# 4  33000.00  aide en numéraire              unique   2019-11-22 00:00:00
#
#    idrae notificationue  pourcentagesubvention  dispositifaide
# 0    NaN            NaN                    1.0             NaN  \
# 1    NaN            NaN                    1.0             NaN
# 2    NaN            NaN                    1.0             NaN
# 3    NaN            NaN                    1.0             NaN
# 4    NaN            NaN                    1.0             NaN
#
#             organization_id      organization
# 0  55df259f88ee386e57a46ec2  Région GRAND EST
# 1  55df259f88ee386e57a46ec2  Région GRAND EST
# 2  55df259f88ee386e57a46ec2  Région GRAND EST
# 3  55df259f88ee386e57a46ec2  Région GRAND EST
# 4  55df259f88ee386e57a46ec2  Région GRAND EST
